# %%
from Historic_Crypto import HistoricalData, Cryptocurrencies
import warnings
from itertools import combinations

warnings.filterwarnings("ignore")

# %%
pairs = ['BTC', 'USDT', 'ETH', 'BNB', 'EUR', 'LTC']

# %%
data = Cryptocurrencies(extended_output=False).find_crypto_pairs()
data
# Out:
# Connected to the CoinBase Pro API.
# Extended Output is False, returning reduced dataset.
#             id display_name  fx_stablecoin max_slippage_percentage  status
# 0      RPL-USD      RPL/USD          False              0.05000000  online
# 1      KRL-EUR      KRL/EUR          False              0.05000000  online
# 2    DESO-USDT    DESO/USDT          False              0.03000000  online
# 3     MANA-EUR     MANA/EUR          False              0.03000000  online
# 4     ANKR-EUR     ANKR/EUR          False              0.03000000  online
# ..         ...          ...            ...                     ...     ...
# 584    OGN-BTC      OGN/BTC          False              0.03000000  online
# 585   AAVE-BTC     AAVE/BTC          False              0.03000000  online
# 586   HFT-USDT     HFT/USDT          False              0.03000000  online
# 587   MANA-ETH     MANA/ETH          False              0.03000000  online
# ...

# %%
assets_prices = {}
for p in combinations(pairs, 2):
    if f'{p[0]}-{p[1]}' in list(data.id):
        pair = f'{p[0]}-{p[1]}'
    elif f'{p[1]}-{p[0]}' in list(data.id):
        pair = f'{p[1]}-{p[0]}'
    else:
        print('Asset pair not found!', f'{p[0]}-{p[1]}')
        continue
    print(('*' * 30) + pair + ('*' * 30))
    assets_prices[pair] = HistoricalData(f'{pair}',60,'2022-01-01-00-00').retrieve_data()
assets_prices
# Out:
# ******************************BTC-USDT******************************
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'BTC-USDT' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2022-01-01T00:00:00
# Provisional End: 2022-01-01T05:00:00
# Data for chunk 1 of 2150 extracted
# Provisional Start: 2022-01-01T05:00:00
# Provisional End: 2022-01-01T10:00:00
# Data for chunk 2 of 2150 extracted
# Provisional Start: 2022-01-01T10:00:00
# Provisional End: 2022-01-01T15:00:00
# Data for chunk 3 of 2150 extracted
# Provisional Start: 2022-01-01T15:00:00
# Provisional End: 2022-01-01T20:00:00
# Data for chunk 4 of 2150 extracted
# Provisional Start: 2022-01-01T20:00:00
# Provisional End: 2022-01-02T01:00:00
# Data for chunk 5 of 2150 extracted
# Provisional Start: 2022-01-02T01:00:00
# Provisional End: 2022-01-02T06:00:00
# ...

# %%
for name, asset in assets_prices.items():
    asset.to_csv(f'../data/coinbase/{name}.csv', index=True)

# %%
assets_prices
# Out:
# {'BTC-USDT':                           low      high      open     close    volume
#  time
#  2022-01-01 00:00:00  46221.22  46257.95  46221.22  46226.81  0.092829
#  2022-01-01 00:01:00  46219.13  46311.86  46219.13  46306.76  0.104787
#  2022-01-01 00:02:00  46291.86  46375.03  46312.41  46351.02  1.666010
#  2022-01-01 00:03:00  46311.30  46371.85  46371.85  46336.69  0.126589
#  2022-01-01 00:04:00  46287.87  46307.73  46307.73  46295.59  0.120649
#  ...                       ...       ...       ...       ...       ...
#  2023-03-24 19:17:00  27807.67  27826.36  27813.02  27820.72  3.753597
#  2023-03-24 19:18:00  27805.36  27829.65  27818.12  27805.36  0.109059
#  2023-03-24 19:20:00  27803.32  27816.61  27805.32  27816.61  0.193936
#  2023-03-24 19:22:00  27828.75  27852.80  27828.75  27845.42  0.090507
#  2023-03-24 19:23:00  27808.39  27829.88  27828.34  27808.39  0.659964
#
#  [489522 rows x 5 columns],
# ...

# %%
assets_prices['LTC-USD'] = HistoricalData('LTC-USD',60,'2022-01-01-00-00').retrieve_data()
assets_prices['LTC-USD'].to_csv(f'../data/coinbase/LTC-USDT.csv', index=True)
# Out:
# Checking input parameters are in the correct format.
# Formatting Dates.
# Checking if user supplied is available on the CoinBase Pro API.
# Connected to the CoinBase Pro API.
# Ticker 'LTC-USD' found at the CoinBase Pro API, continuing to extraction.
# Provisional Start: 2022-01-01T00:00:00
# Provisional End: 2022-01-01T05:00:00
# Data for chunk 1 of 2153 extracted
# Provisional Start: 2022-01-01T05:00:00
# Provisional End: 2022-01-01T10:00:00
# Data for chunk 2 of 2153 extracted
# Provisional Start: 2022-01-01T10:00:00
# Provisional End: 2022-01-01T15:00:00
# Data for chunk 3 of 2153 extracted
# Provisional Start: 2022-01-01T15:00:00
# Provisional End: 2022-01-01T20:00:00
# Data for chunk 4 of 2153 extracted
# Provisional Start: 2022-01-01T20:00:00
# Provisional End: 2022-01-02T01:00:00
# Data for chunk 5 of 2153 extracted
# Provisional Start: 2022-01-02T01:00:00
# Provisional End: 2022-01-02T06:00:00
# Data for chunk 6 of 2153 extracted
# Provisional Start: 2022-01-02T06:00:00
# ...

# %%
data[data['id'].str.contains('LTC')]
# Out:
#           id display_name  fx_stablecoin max_slippage_percentage  status
# 141  LTC-GBP      LTC/GBP          False              0.03000000  online
# 317  LTC-EUR      LTC/EUR          False              0.03000000  online
# 346  LTC-BTC      LTC/BTC          False              0.03000000  online
# 571  LTC-USD      LTC/USD          False              0.03000000  online
